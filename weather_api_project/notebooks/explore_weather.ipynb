# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Reads the br_final csv file, then stores that info in the data variable.

# %%
csv = pd.read_csv("/Users/leilastambuli/Documents/The Knowledge House/KnowledgeHouse20242025/weather_api_project/data/csv/br_final.csv")
data = csv

sns.lineplot(data, x="year", y="million_60kgs_bag", hue="subdivision", marker="o").set_title("Million 60kg Bags in Subdivisions Over Years")
# Out:
# Text(0.5, 1.0, 'Million 60kg Bags in Subdivisions Over Years')

# %% [markdown]
# The harvest has varied over the years for the 4 subdivisions. Minas Gerais has a higher harvest yield than the other 3 subdivisions despite overall declines.
